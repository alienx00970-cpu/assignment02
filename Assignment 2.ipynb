# %% [markdown]
# ### Calculating following expression and printing result
# ### 30 + 4 × 3 − 6

# %%
#Calculate and write the output of the following expression:
# Question # 01
result = 30 + 4 * 3 - 6

print(result)
# Out:
# 36

# %% [markdown]
# ### Calculating following expression and printing result
# ### 100 ÷ 4 + 7 − 5

# %%
# Calculate and write the output of the following expression:
# Question # 02
result = 100 / 4 + 7 - 5

print(result)
# Out:
# 27.0

# %% [markdown]
# ### Creating string and converting it in integer and determine it's data type

# %%
# Create a variable containing the string value "100". Convert it into an integer and display its data type before and after conversion.
# Question # 03
value = "100"

print(type(value))

value = int(value)

print(type(value))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ### Creating lists and filtering elements

# %%
# Create the following list and display cities:
# Question # 04
cities = ["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]

print(cities[1])

print(cities[3])
# We use one number behind from the real position as python starts it's counting from zero 0
# Out:
# Lahore
# Peshawar

# %% [markdown]
# ### Print Students Name

# %%
# Create the following nested list and display:
# Question # 05
students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
# For Ali
print(students[0][0])
# For Ayesha 
print(students[1][0])
# Out:
# Ali
# Ayesha

# %% [markdown]
# ### Element Slicing

# %%
# From the given list display the first 3 and the last 3 elements:
# Question # 06
numbers = [10,20,30,40,50,60,70]

print(numbers[:3])

print(numbers[-3:])
# Out:
# [10, 20, 30]
# [50, 60, 70]

# %% [markdown]
# ### Element Slicing

# %%
# From the given list display the name of the first student and the age of the last student:
# Question # 07
students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]

print(students[0][0])

print(students[1][1])
# Out:
# Ali
# 22

# %% [markdown]
# ### Print Fruit names

# %%
# Create a list of 5 fruits and display the first and the last fruit:
# Question # 08
fruits = ["Apple","Mango","Banana","Pear","Kiwi"]

print(fruits[0])

print(fruits[4])
# Out:
# Apple
# Kiwi

# %% [markdown]
# ### Displaying color names using negative indexing

# %%
# Create the following list and display the first and the last color using negative indexing:
# Question # 09
colors = ["Red", "Blue", "Green", "Yellow", "Black"]

print(colors[0])

print(colors[-1])
# Out:
# Red
# Black

# %% [markdown]
# ### Displaying marks using nested list

# %%
# Given Nested list display the subject of second student and marks of third student
# Question # 10
marks = [["Math", 90], ["Physics", 85], ["English", 88]]

print(marks[1][0])


print(marks[2][1])
# Out:
# Physics
# 88
