# %% [markdown]
# ### Age Group Classification
# ### Question # 01

# %%
# Question # 01
# Write a Python program that takes the age of a person as input and classifies them into one of the following age groups:
# "Child" if the age is between 0 and 12 (inclusive).
# "Teenager" if the age is between 13 and 19 (inclusive).
# "Adult" if the age is between 20 and 64 (inclusive).
# "Senior" if the age is 65 or older.
age = int(input("Enter your age : "))

if age <= (12):
    print("Child")
elif age <= (19):
    print("Teenager")
elif age <= (64) :
    print("Adult")
else :
    print("Senior")
# Out:
# Enter your age :  11
# Child

# %% [markdown]
# ### Largest among three numbers
# ### Question # 02

# %%
# Question # 02 
# Write a Python program that takes three numbers as input and determines the largest among them. Also, check if any or all of the numbers are equal.
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))

if num1 == num2 == num3:
    print("All numbers are equal")
elif num1 == num2 or num2 == num3 or num1 == num3:
    print("Two numbers are equal")
    
if num1 >= num2 and num1 >= num3:
    print(f"The largest number is: {num1}")
elif num2 >= num1 and num2 >= num3:
    print(f"The largest number is: {num2}")
else:
    print(f"The largest number is: {num3}")
# Out:
# Enter first number:  10
# Enter second number:  11
# Enter third number:  12
# The largest number is: 12

# %% [markdown]
# ### Check if Number Exists in Tuple
# ### Question # 03

# %%
# Question # 03
# Take an integer input from the user and check whether the entered value exists in the tuple my_tuple = (5, 10, 15, 20, 25).
# Print an appropriate message based on the result.
my_tuple = (5, 10, 15, 20, 25)
num = int(input("Enter a number: "))

if num in my_tuple:
    print(f"{num} exists in the tuple")
else:
    print(f"{num} does not exist in the tuple")
# Out:
# Enter a number:  30
# 30 does not exist in the tuple

# %% [markdown]
# ### Book Details Storage and Display
# ### Question # 04

# %%
# Question # 04 
# Write a Python program to store and display the details of a book. The program should ask the user to input the following information:
# Title of the book , Author’s name , Year of publication , Price of the booK , Store the entered details in a tuple.
# Finally, display the book details in a proper format as shotitle = input("Enter the title of the book: ")
title = input("Enter the title of the book: ")
author = input("Enter the author's name: ")
year = int(input("Enter the year of publication: "))
price = float(input("Enter the price of the book: "))

book_details = (title, author, year, price)

print("\nBook Details:")
print(f"Title: {book_details[0]}")
print(f"Author: {book_details[1]}")
print(f"Year of Publication: {book_details[2]}")
print(f"Price: ${book_details[3]}")
# Out:
# Enter the title of the book:  Harry Potter
# Enter the author's name:  JK Rowlings
# Enter the year of publication:  2000
# Enter the price of the book:  180
# Book Details:
# Title: Harry Potter
# Author: JK Rowlings
# Year of Publication: 2000
# Price: $180.0

# %% [markdown]
# ### Subject Availability Check
# ### Question # 05

# %%
# Question # 05
# Write a program to check if a user’s chosen subject is available in the list of offered subjects.
# Given a list of subjects, ask the user to input a subject.
# Display whether the subject is available or not.
subjects = ["computer science", "medical science", "pre engineering", "commerce", "arts", "humanities"]
user_subject = input("Enter the subject you are interested in: ").lower()

if user_subject in subjects:
    print(f"{user_subject} is available.")
else:
    print(f"{user_subject} is not available.")
# Out:
# Enter the subject you are interested in:  Arts
# arts is available.

# %% [markdown]
# ### Positive,Negative,or Zero
# ### Question # 06

# %%
# Question # 06 
# Write a Python program that asks the user to enter a number.
# If the number is greater than 0, print "Positive". If the number is less than 0, print "Negative". If the number is exactly 0, print "Zero".
num = int(input("Enter a Number: "))
if num > 0:
    print("Number is positive")
elif num < 0:
    print("Number is Negative")
else:
    print("Number is Zero")
# Out:
# Enter a Number:  -45
# Number is Negative

# %% [markdown]
# ###  Simple Login System
# ### Question # 07

# %%
# Question # 07
# Write a Python program that simulates a simple login system.The correct username is 'admin' and the correct password is 'admin@123'
# The program should take username and password as input from the user.It should check the input and display messages according to the following 
# conditions
# If both username and password are correct → print "Login Successful".
# If username is wrong but password is correct → print "Invalid Username".
# If username is correct but password is wrong → print "Invalid Password".
# If both username and password are wrong → print "Invalid Username and Password".
correct_username = "admin"
correct_password = "admin@123"

username = input("Enter username: ")
password = input("Enter password: ")

if username == correct_username and password == correct_password:
    print("Login Successful")
elif username != correct_username and password == correct_password:
    print("Invalid Username")
elif username == correct_username and password != correct_password:
    print("Invalid Password")
else:
    print("Invalid Username and Password")
# Out:
# Enter username:  admin
# Enter password:  admin@123
# Login Successful

# %% [markdown]
# ###  Loan Eligibility Check
# ### Question # 09

# %%
# Question # 09 
# Write program to check a person’s eligibility for a loan based on age, credit score, and income. This time, the eligibility criteria will be:
# The person must be 18 years or older. The person must have a credit score of 650 or higher. 
# The person must have an annual income of at least 30000 dollars If the person has a credit score of 700 or higher, 
# they may still be eligible with an income of 25000 dollars or more.
age = int(input("Enter your age: "))
credit_score = int(input("Enter your credit score: "))
income = float(input("Enter your annual income: $ "))

if age < 18:
    print("You are not eligible for the loan due to age.")
elif credit_score < 650:
    print("You are not eligible for the loan due to low credit score.")
elif income < 30000:
    if credit_score >= 700 and income >= 25000:
        print("You are eligible for the loan!")
    else:
        print("You are not eligible for the loan due to low income.")
else:
    print("You are eligible for the loan!")
# Out:
# Enter your age:  15
# Enter your credit score:  800
# Enter your annual income: $  900000
# You are not eligible for the loan due to age.

# %% [markdown]
# ### Vowel,Consonant, or Invalid input
# ### Question # 10

# %%
# Question # 10
#  Write a Python program to check whether the entered letter is a vowel, a consonant, or invalid input.
# The program should take a single character as input. If the character is a vowel (a, e, i, o, u in both upper and lower case), it will print "Vowel".
# If it is an alphabet but not a vowel, it will print "Consonant". Otherwise, it will print "Please enter valid alphabet".
character = input("Enter a single letter: ")

if len(character) != 1:
    print("Please enter valid alphabet")
else:
    if character.isalpha():
        if character.lower() in 'aeiou':
            print(f"{character} is a Vowel")
        else:
            print(f"{character} is a Consonant")
    else:
        print("Please enter valid alphabet")
# Out:
# Enter a single letter:  a
# a is a Vowel
